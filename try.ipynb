# %%
import scipy.io
mat = scipy.io.loadmat('pl.mat')
import matplotlib.pyplot as plt
from PIL import Image
import  os

# %%
mat['labels'].shape
# Out:
# (1, 8189)

# %%
mat['labels'][0][97]
# Out:
# 77

# %%
data_folder = './Dataset/jpg/'
dataset = os.listdir(data_folder)

# %%
from labels import labels

# %%
labels[mat['labels'][0][97]-1]
# Out:
# 'passion flower'

# %%
from random import randint

# %%
index = randint(0,len(dataset))
img = Image.open(data_folder+dataset[index])
plt.imshow(img)
plt.title(labels[mat['labels'][0][index]-1])
# Out:
# Text(0.5, 1.0, 'black-eyed susan')

# %%
dataset
# Out:
# ['image_00001.jpg',
#  'image_00002.jpg',
#  'image_00003.jpg',
#  'image_00004.jpg',
#  'image_00005.jpg',
#  'image_00006.jpg',
#  'image_00007.jpg',
#  'image_00008.jpg',
#  'image_00009.jpg',
#  'image_00010.jpg',
#  'image_00011.jpg',
#  'image_00012.jpg',
#  'image_00013.jpg',
#  'image_00014.jpg',
#  'image_00015.jpg',
#  'image_00016.jpg',
#  'image_00017.jpg',
#  'image_00018.jpg',
#  'image_00019.jpg',
#  'image_00020.jpg',
#  'image_00021.jpg',
#  'image_00022.jpg',
#  'image_00023.jpg',
#  'image_00024.jpg',
#  'image_00025.jpg',
#  'image_00026.jpg',
#  'image_00027.jpg',
#  'image_00028.jpg',
#  'image_00029.jpg',
#  'image_00030.jpg',
#  'image_00031.jpg',
#  'image_00032.jpg',
#  'image_00033.jpg',
#  'image_00034.jpg',
#  'image_00035.jpg',
#  'image_00036.jpg',
#  'image_00037.jpg',
#  'image_00038.jpg',
#  'image_00039.jpg',
#  'image_00040.jpg',
#  'image_00041.jpg',
#  'image_00042.jpg',
#  'image_00043.jpg',
#  'image_00044.jpg',
#  'image_00045.jpg',
# ...
